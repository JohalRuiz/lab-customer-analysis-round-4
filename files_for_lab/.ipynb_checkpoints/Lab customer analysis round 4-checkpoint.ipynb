# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
df1 = pd.read_csv('Lab_customer_analysis_round_2.csv')

# %%
#df1.columns

# %%
df1 = df1.drop(columns = ['Unnamed: 0'])
df1
# Out:
#      customer       state  customer_lifetime_value response  coverage  \
# 0     PB63095  Washington              5568.947534      Yes  Extended
# 1     XJ97760  California              4739.861234       No     Basic
# 2     RA27021      Nevada             27564.739510       No  Extended
# 3     OG30514      Nevada             20018.204590       No     Basic
# 4     GJ44951  Washington              4698.759935       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  XA55917  California              8533.832013       No     Basic
# 9130  KM65135      Oregon              4763.327142       No     Basic
# 9131  EB61889  California              9486.037005       No  Extended
# 9132  SB83749  California              4717.628730       No     Basic
# 9133  AU46443      Nevada              7517.083811       No     Basic
#
#                  education effective_to_date employment_status gender  income  \
# ...

# %%
#Check the data types of the columns
df1.dtypes
# Out:
# customer                          object
# state                             object
# customer_lifetime_value          float64
# response                          object
# coverage                          object
# education                         object
# effective_to_date                 object
# employment_status                 object
# gender                            object
# income                             int64
# location_code                     object
# marital_status                    object
# monthly_premium_auto               int64
# months_since_last_claim            int64
# months_since_policy_inception      int64
# number_of_open_complaints          int64
# number_of_policies                 int64
# policy_type                       object
# policy                            object
# renew_offer_type                  object
# sales_channel                     object
# total_claim_amount               float64
# vehicle_class                     object
# ...

# %%
# Get the numeric data into dataframe called numerical [...]

# %%
numeric_types = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
numerical = df1.select_dtypes(include=numeric_types)
numerical.head(3)
# Out:
#    customer_lifetime_value  income  monthly_premium_auto  \
# 0              5568.947534       0                    79
# 1              4739.861234   35039                    61
# 2             27564.739510   26410                    91
#
#    months_since_last_claim  months_since_policy_inception  \
# 0                       21                             53
# 1                        7                             87
# 2                       17                             90
#
#    number_of_open_complaints  number_of_policies  total_claim_amount
# 0                          1                   7          407.440238
# 1                          0                   8          254.308991
# 2                          0                   2          184.516188

# %%
# [...] and categorical columns in a dataframe called categoricals
categoricals = df1.select_dtypes(exclude=numeric_types)
categoricals.head(3)
# Out:
#   customer       state response  coverage             education  \
# 0  PB63095  Washington      Yes  Extended  High School or Below
# 1  XJ97760  California       No     Basic                Master
# 2  RA27021      Nevada       No  Extended              Bachelor
#
#   effective_to_date employment_status gender location_code marital_status  \
# 0        2011-01-01        Unemployed      M      Suburban         Single
# 1        2011-01-01          Employed      M         Urban         Single
# 2        2011-01-01          Disabled      F         Rural        Married
#
#       policy_type        policy renew_offer_type sales_channel  vehicle_class  \
# 0   Personal Auto   Personal L2           Offer1         Agent   Two-Door Car
# 1   Personal Auto   Personal L1           Offer1   Call Center  Four-Door Car
# 2  Corporate Auto  Corporate L1           Offer2         Agent  Four-Door Car
#
#   vehicle_size effective_to_month
# 0      Medsize            2011-01
# ...

# %%
# Use seaborn library to construct distribution plots for the numerical variables

# %%
sns.displot(numerical['customer_lifetime_value'])
plt.show()
sns.histplot(numerical['customer_lifetime_value'])
plt.show()
sns.kdeplot(numerical['customer_lifetime_value'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d335dd08f6bf> in <module>
# ----> 1 sns.displot(numerical['customer_lifetime_value'])
#       2 plt.show()
#       3 sns.histplot(numerical['customer_lifetime_value'])
#       4 plt.show()
#       5 sns.kdeplot(numerical['customer_lifetime_value'])
#
# NameError: name 'sns' is not defined

# %%
sns.displot(numerical['income'])
plt.show()
sns.histplot(numerical['income'])
plt.show()
sns.kdeplot(numerical['income'])
plt.show()

# %%
sns.displot(numerical['monthly_premium_auto'])
plt.show()
sns.histplot(numerical['monthly_premium_auto'])
plt.show()
sns.kdeplot(numerical['monthly_premium_auto'])
plt.show()

# %%
sns.displot(numerical['months_since_last_claim'])
plt.show()
sns.histplot(numerical['months_since_last_claim'])
plt.show()
sns.kdeplot(numerical['months_since_last_claim'])
plt.show()

# %%
sns.displot(numerical['months_since_policy_inception'])
plt.show()
sns.histplot(numerical['months_since_policy_inception'])
plt.show()
sns.kdeplot(numerical['months_since_policy_inception'])
plt.show()

# %%
sns.displot(numerical['months_since_policy_inception'])
plt.show()
sns.histplot(numerical['months_since_policy_inception'])
plt.show()
sns.kdeplot(numerical['months_since_policy_inception'])
plt.show()

# %%
sns.displot(numerical['number_of_open_complaints'])
plt.show()
sns.histplot(numerical['number_of_open_complaints'])
plt.show()
sns.kdeplot(numerical['number_of_open_complaints'])
plt.show()

# %%
sns.displot(numerical['number_of_policies'])
plt.show()
sns.histplot(numerical['number_of_policies'])
plt.show()
sns.kdeplot(numerical['number_of_policies'])
plt.show()

# %%
sns.displot(numerical['total_claim_amount'])
plt.show()
sns.histplot(numerical['total_claim_amount'])
plt.show()
sns.kdeplot(numerical['total_claim_amount'])
plt.show()

# %%
# sns.scatterplot(y, blabla)

# %%
# Show a plot of the total number of responses:
sns.countplot(x='response', data=df1)
plt.show()

# %%
# Show a plot of the response rate by the sales channel:
sns.countplot(x='response', hue='sales_channel', data=df1)
plt.show()

# %%
#df2 = df1.copy()

# %%
# Show a plot of the response rate by the total claim amount:
sns.barplot(x='response', y='total_claim_amount', data=df1)
plt.show()

# %%
sns.boxplot(x='response', y='total_claim_amount', data=df1)
plt.show()

# %%
# Show a plot of the response rate by income:
sns.barplot(x='response', y='income', data=df1)
plt.show()

# %%
sns.boxplot(x='response', y='income', data=df1)
plt.show()
